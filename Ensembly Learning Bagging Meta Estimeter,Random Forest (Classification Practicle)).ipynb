# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons

# %%
x,y = make_moons(n_samples=1000,noise=0.2)

# %%
df = {"x1":x[:,0],"x2":x[:,1],"y":y}

# %%
dataset = pd.DataFrame(df)

# %%
dataset.head()
# Out:
#          x1        x2  y
# 0  1.017484  0.881594  0
# 1  2.211251 -0.270250  1
# 2  1.753393 -0.124776  1
# 3  0.653579  0.886593  0
# 4 -0.827672  0.255889  0

# %%
sns.scatterplot(x="x1",y="x2",data=dataset,hue="y")
plt.plot()
# Out:
# []

# %%
x_a = dataset.iloc[:,:-1]
y_a = dataset["y"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
sv = SVC()
sv.fit(x_train,y_train)
sv.score(x_train,y_train)*100 , sv.score(x_test,y_test)*100
# Out:
# (97.625, 95.5)

# %%
bg = BaggingClassifier(estimator=SVC(),n_estimators=100)
bg.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=SVC(), n_estimators=100)

# %%
bg.score(x_train,y_train)*100,bg.score(x_test,y_test)*100
# Out:
# (97.625, 95.5)

# %%
rf = RandomForestClassifier( n_estimators=30)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)*100 , rf.score(x_test,y_test)*100
# Out:
# (100.0, 95.5)
