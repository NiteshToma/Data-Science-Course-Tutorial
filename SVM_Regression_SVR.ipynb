# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.read_excel("placement.xlsx")
df.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
x = df[["cgpa"]]
y = df["package"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVR
sv = SVR(kernel="poly")
sv.fit(x_train,y_train)
# Out:
# SVR(kernel='poly')

# %%
sv.score(x_test,y_test)*100
# Out:
# 72.30726378194225

# %%
sv.score(x_train,y_train)*100
# Out:
# 73.70560958175587

# %%
sns.scatterplot(x="cgpa",y="package",data=df)
plt.scatter(df["cgpa"],sv.predict(x),color="red")
plt.show()

# %%
df1 = pd.read_excel("Position_Salaries.xlsx")
df1.head()
# Out:
#    Level  Salary
# 0      1   45000
# 1      2   50000
# 2      3   60000
# 3      4   80000
# 4      5  110000

# %%
sns.scatterplot(x="Level",y="Salary",data=df1)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x = df1[["Level"]]
y = df1["Salary"]

# %%
from sklearn.svm import SVR
sv1 = SVR(kernel="poly")
sv1.fit(x_train,y_train)
# Out:
# SVR(kernel='poly')

# %%
sv1.score(x_test,y_test)*100
# Out:
# -39.42794958376392

# %%
sv1.score(x_train,y_train)*100
# Out:
# -13.412146755309507

# %%
sns.scatterplot(x="Level",y="Salary",data=df1)
plt.scatter(df1["Level"],sv1.predict(x),color="red")
plt.show()
