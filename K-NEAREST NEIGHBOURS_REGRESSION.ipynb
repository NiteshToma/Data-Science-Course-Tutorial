# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Salary_Data.xlsx")
df.head()
# Out:
#     Age  Salary  Experience
# 0  21.0   39343         9.7
# 1  21.5   46205         7.9
# 2  21.7   37731         3.8
# 3  22.0   43525         9.1
# 4  22.2   39891        11.4

# %%
df.isnull().sum()
# Out:
# Age           0
# Salary        0
# Experience    0
# dtype: int64

# %%
x = df.drop(columns="Salary")
y = df["Salary"]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=2)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
knn.score(x_test,y_test)*100
# Out:
# 65.0169644317374

# %%
for i in range(1,20):
    knn1 = KNeighborsRegressor(n_neighbors=i)
    knn1.fit(x_train,y_train)
    print(i,knn1.score(x_train,y_train),knn1.score(x_test,y_test)*100)
# Out:
# 1 0.9993291284279773 51.32343202993685
# 2 0.9589492819051049 65.0169644317374
# 3 0.962256298534025 49.01143512476159
# 4 0.9443383021094471 59.80360324042269
# 5 0.9315207757224769 45.286517657240275
# 6 0.9348645360376266 49.605511926236545
# 7 0.9060238866987227 49.9241785311512
# 8 0.8768581111910452 46.612413020821684
# 9 0.8498789343331212 38.51934983898765
# 10 0.8080971443542011 37.39700758616195
# 11 0.7689253768430346 38.77199035772916
# 12 0.7082648481340755 28.84346232297088
# 13 0.6613833086150198 16.87278256173339
# 14 0.6259140700467651 20.189384819116462
# 15 0.6137141322733051 16.305597247962776
# 16 0.5723543559842874 13.572141537892335
# 17 0.5223195871992896 12.133796985993882
# 18 0.4686141656131825 5.292500402049072
# 19 0.40400867294093 0.8515892960281324
